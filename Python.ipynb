# %%
terms = ["E"]

for _ in range(3):
    new_terms = []

    for term in terms:
        for i, y in enumerate(term):
            if y == "E":
                new_term = term[:i] + "JEE" + term[i+1:]

                if new_term not in new_terms and new_term not in terms:
                    new_terms.append(new_term)

    terms.extend(new_terms)

print(terms)
# Out:
# ['E', 'JEE', 'JJEEE', 'JEJEE', 'JJJEEEE', 'JJEJEEE', 'JJEEJEE', 'JEJJEEE', 'JEJEJEE']

# %%
elementof_op = ["∈"]
eq_op = ["="]

WFF = []
for i in terms:
    for y in terms:
        if y == i: 
            continue 
        AFO = [i] + elementof_op + [y] 
        AFE = [i] + eq_op + [y]

        WFF.append(AFE)
        WFF.append(AFO)

# %%
or_op = ["∨"]
imply_op = ["⇒"]
and_op = ["∧"]
not_op = ["¬"]

Propositions = []

for i in WFF:
    for y in WFF:
        if y == i:
            continue

        Proposition_or = [i] + or_op + [y]
        Proposition_and = [i] + and_op + [y]
        Proposition_imply = [i] + imply_op + [y]

        Propositions.append(Proposition_or)
        Propositions.append(Proposition_and)
        Propositions.append(Proposition_imply)


    Proposition_not = not_op + [i]
    Propositions.append(Proposition_not)

# %%
halt = False

for p_idx in range(len(Propositions)):
    if halt:
        break

    prop = Propositions[p_idx]
    rows = [[0] * len(WFF)]
    true_count = 0

    for _ in range(len(WFF)):
        row = rows[-1]

        firstboolean = 0
        secondboolean = 0

        for i, term in enumerate(WFF):
            if prop[0] == term:
                firstboolean = row[i]
            if len(prop) > 2 and prop[2] == term:
                secondboolean = row[i]
            if prop[0] == "¬" and prop[1] == term:
                firstboolean = row[i]

        result = False

        if prop[1] == "∨":
            if firstboolean == 1 or secondboolean == 1:
                result = True
        if prop[1] == "∧":
            if firstboolean == 1 and secondboolean == 1:
                result = True
        if prop[1] == "⇒":
            if firstboolean == 0 or secondboolean == 1:
                result = True
        if prop[0] == "¬":
            if firstboolean == 0:
                result = True

        if not result:
            print(prop)
            break

        true_count = true_count + 1

        new_row = list(row)
        for b in range(len(new_row)):
            if new_row[b] == 0:
                new_row[b] = 1
                break
            else:
                new_row[b] = 0
        rows.append(new_row)

    if true_count == len(WFF):
        print("halt")
        print(prop)
        halt = True
# Out:
# [['E', '=', 'JEE'], '∨', ['E', '∈', 'JEE']]
# [['E', '=', 'JEE'], '∧', ['E', '∈', 'JEE']]
# [['E', '=', 'JEE'], '⇒', ['E', '∈', 'JEE']]
# [['E', '=', 'JEE'], '∨', ['E', '=', 'JJEEE']]
# [['E', '=', 'JEE'], '∧', ['E', '=', 'JJEEE']]
# [['E', '=', 'JEE'], '⇒', ['E', '=', 'JJEEE']]
# [['E', '=', 'JEE'], '∨', ['E', '∈', 'JJEEE']]
# [['E', '=', 'JEE'], '∧', ['E', '∈', 'JJEEE']]
# [['E', '=', 'JEE'], '⇒', ['E', '∈', 'JJEEE']]
# [['E', '=', 'JEE'], '∨', ['E', '=', 'JEJEE']]
# [['E', '=', 'JEE'], '∧', ['E', '=', 'JEJEE']]
# [['E', '=', 'JEE'], '⇒', ['E', '=', 'JEJEE']]
# [['E', '=', 'JEE'], '∨', ['E', '∈', 'JEJEE']]
# [['E', '=', 'JEE'], '∧', ['E', '∈', 'JEJEE']]
# [['E', '=', 'JEE'], '⇒', ['E', '∈', 'JEJEE']]
# [['E', '=', 'JEE'], '∨', ['E', '=', 'JJJEEEE']]
# [['E', '=', 'JEE'], '∧', ['E', '=', 'JJJEEEE']]
# [['E', '=', 'JEE'], '⇒', ['E', '=', 'JJJEEEE']]
# [['E', '=', 'JEE'], '∨', ['E', '∈', 'JJJEEEE']]
# [['E', '=', 'JEE'], '∧', ['E', '∈', 'JJJEEEE']]
# ...
